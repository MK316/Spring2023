# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2023/blob/main/Engpro/Lesson9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌀**Lesson 9: R-coloured vowels in American English**

# %% [markdown]
# # 🌱 Settings:
#
# + American English: etts(),
# + British English: btts(),
# + Canadian English: ctts()
# + Korean: ktts(),

# %%
#@markdown 🔄 Install and import libraries
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio, Image, YouTubeVideo

# %%
#@markdown 🔄 Making functions: etts('text'), ktts('text'), btts('text)
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def etts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "us",
                    slow = False)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def ktts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "ko",
                    slow = False)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def btts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "co.uk",
                    slow = False)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def ctts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "ca",
                    slow = False)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

# %% [markdown]
# # Accent comparison
#
# [video link](https://www.youtube.com/watch?v=R1lmeSIhLxc)

# %%
#@markdown 🎬 ONE language, THREE accents
from IPython.display import YouTubeVideo, display
video = YouTubeVideo("R1lmeSIhLxc", width=800, height="600")
display(video)

# %% [markdown]
# # 'r' sound in different positions

# %% [markdown]
# ## A. In stressed syllables

# %%
positions = "1_word-initial" #@param = ["1_word-initial", "2_word-medial", "3_word-final"]
accents = "BrE" #@param = ["AmE","BrE"]

pos = positions.split("_")
num = pos[0]
n=int(num)-1

wordlist = ["earth, earn, irk, herb, early, urgent, urban",
            "turn, burn, learn, heard, verb, word, curve, third, Thursday, circus, bird, firm, hurt, term",
            "sir, her, fur, prefer, defer, occur"]
wd = wordlist[n]
intro2 = pos[1]
mytxt = "Let me say some English words appearing in %s. Listen how the R sound is pronounced. "%intro2 + wd

if accents == "AmE":
  etts(mytxt)
elif accents == "BrE":
  btts(mytxt)

Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## B. In unstressed syllables

# %%
positions = "1_word-initial" #@param = ["1_word-initial", "2_word-medial", "3_word-final"]
accents = "BrE" #@param = ["AmE","BrE"]

pos = positions.split("_")
num = pos[0]
n=int(num)-1

wordlist = ["No English word is found containing this syllable in this position",
            "Words in medial position: turn, burn, learn, heard, verb, word, curve, third, Thursday, circus, bird, firm, hurt, term",
            "Words in final position: sir, her, fur, prefer, defer, occur"]
wd = wordlist[n]
intro2 = pos[1]
mytxt = wd

if accents == "AmE":
  etts(mytxt)
elif accents == "BrE":
  btts(mytxt)

Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # How to pronounce '-rl' together?
#
# + rl:  "girl, curl, world, pearl, early"
# + r:   "sir, fur, word, per, err",
# + l:   "gull, cull, wall, paul, all"

# %%
#@markdown girl, curl, world, pearl, early

words = "1_words with rl" #@param = ["1_words with rl", "2_ words with r", "3_words with l"]
accents = "American" #@param = ["American", "British"]
wd = words.split("_")
at = accents.split(" ")

num = int(wd[0])
n = num -1

wordlist = ["girl, curl, world, pearl, early", 
            "sir, fur, word, per, err",
            "gull, cull, wall, paul, all"]

txt = "Here's the word sample: " + wordlist[n]

if accents == "American":
  etts(txt)
elif accents == "British":
  btts(txt)

Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
