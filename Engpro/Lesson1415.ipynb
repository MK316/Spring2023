# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2023/blob/main/Engpro/Lesson1415.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Engpro: Lession 14 Introduction

# %%
#@markdown Setup

# !pip install gtts
from gtts import gTTS
import pandas as pd
from IPython.display import Audio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# #[1] Spelling and sounds in English

# %%
#@markdown Define etts(), 'sample.mp3'
def etts(mytext):
    tts = gTTS(mytext)
    tts.save('sample.mp3')
    return Audio('sample.mp3', autoplay=True)

# %%
#@markdown Button control TTS
from gtts import gTTS
from IPython.display import Audio
import ipywidgets as widgets

def etts(mytext, lang='en', dialect=None, slow=False):
    if slow:
        speed = 0.5
    else:
        speed = 1.0
    
    if dialect:
        lang_code = f"{lang}-{dialect}"
    else:
        lang_code = lang
    
    tts = gTTS(mytext, lang=lang_code, slow=slow)
    tts.speed = speed
    tts.save('sample.mp3')
    return Audio('sample.mp3', autoplay=True)

# Define the language and dialect options
languages = {
    'English': 'en',
    'French': 'fr',
    'German': 'de',
    'Italian': 'it',
    'Japanese': 'ja',
    'Korean': 'ko',
    'Spanish': 'es',
    'Russian': 'ru'
}

# Create the language and dialect dropdown widgets
lang_dropdown = widgets.Dropdown(options=languages, value='en', description='Language:')

# Create the slow checkbox widget
slow_checkbox = widgets.Checkbox(value=False, description='Slow')

# Define a function to handle the button click event
def on_button_click(btn):
    lang = lang_dropdown.value
    display(etts(input_text.value, lang=lang, slow=False))

# Create the text input widget and button
input_text = widgets.Text(description='Text:')
btn = widgets.Button(description='Speak')
btn.on_click(on_button_click)

# Display the widgets
display(widgets.VBox([input_text, lang_dropdown, slow_checkbox, btn]))

# %%
spelling = "1. ch-k" #@param = ["1. ch-k", "2. ch-tʃ", "3. s-s", "4. s-z"]
sn1 = spelling.split(".")
sn2 = sn1[0]
sn3 = int(sn2) -1

wordlist=['chaos, stomach, mechanic, character, echo, technology, anchor, architect, monarch, epoch, stomachache, orchestra, chemistry, Christmas, chrome, chronic, chickpea, backpack, checkmate, hiccup',
'chair. choose. change. chapter. cheddar. cheap. chimney. cheese. church. chocolate. check. charm. challenge. champion. chancellor. charge. cherish. chicken',
'sun. sister. salt. sit. sand. sound. seen. sing. sorry. season. success. satisfy. suspense. session. satisfy. science. discuss. dessert. listen. present',
"'reason', 'roses', 'museum', 'laser', 'results', 'freezes', 'has', 'was', 'does', 'is', 'eyes', 'easy', 'please', 'raise', 'presents', 'houses', 'music'",
]

myword = wordlist[sn3]
etts(myword)

Audio("sample.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# [p. 76] Circle all the consonants included in the sentence you'd hear.

# %%
spelling = "2. Sentence1" #@param = ["1. voicing", "2. Sentence1", "3. Sentence2", "4. Sentence3"]
sn1 = spelling.split(".")
sn2 = sn1[0]
sn3 = int(sn2) -1

wordlist=["pie vs. bye, teen vs. dean, Kate vs. gate, leaf vs. leave, breath vs. breathe, face vs. phase, pressure vs. pleasure, batch vs. badge.",
          "The sun is shining and the birds are singing outside my window.",
          "Yesterday, I went for a walk in the woods and saw a family of deer.",
          "After a long day at work, I enjoy reading a good book in bed."
]

myword = wordlist[sn3]
etts(myword)

Audio("sample.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Lesson 15. face vs. phase; pressure vs. pleasure; church vs. judge

# %% [markdown]
# ## Consonant chart

# %%
sound = "12. More practice" #@param = ["1. /s/ begining", "2. /s/ middle", "3. /s/ Ending", "4. /z/ beginning", "5. /z/ middle", "6. /z/ ending", "7. /s-z/ contrast beginning", "8. /s-z/ contrast middle", "9. sh all ","10. zh all ", "11. [tʃ] and [dʒ]", "12. More practice"]
sn1 = sound.split(".")
sn2 = sn1[0]
sn3 = int(sn2) - 1

soundlist =["same, sign, city, cinema, signature, system, sorry",
           "lesson, custom,castle, history", 
           "bus, face, course, makes, miss, house, plus",
           "zoo, zero, zest, zeal, zone, zinc, zipper, zebra",
           "crazy, busy, easy, dizzy, cousin, puzzle, dozen, his",
           "as, was, raise, is, buzz, his, breeze, amaze",
           "Sue vs. zoo, face vs. phase, race vs. raise, bus, vs. buzz",
           "ice vs. eyes, place vs. plays, peace vs. peaz, price vs. prize, racer vs. razor",
           "shine, shame, sugar, fashion, cushion, fish, cash, smash",
           "pleasure, measure, leisure, vision, decision, television, lesion, occasion, usual, Asia, conclusion, beige, garage, camouflage, entourage, rouge, regime, massage.",
           "cash vs. catch, smash vs. match, fish vs. beige, fiction vs. vision, garage vs. cage, pleasure vs. pledge, amaze, garage, and engage, user, illusion, James",
          "Number 1. chess and Jess; 2. Jack, and Zack; 3. chew and Jew; 4. zoo and Jew; 5. heads and hedge; 6. zone and Joan; 7. bays and beige; 8. ruse and rouge; 9. Caesar and seizure; 10. version and virgin; 11. lesion and legion; 12. pleasure and pledger. "
]

mysound = soundlist[sn3]
etts(mysound)

Audio("sample.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
