# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2023/blob/main/Engpro/Engpro_Lesson5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 5. Vowel pair 4: [ɑ] as in ‘father' (cf. Korean '아')

# %% [markdown]
# ## 📌 Setting ups

# %%
#@markdown 💠 Import libraries {Image, Audio, YouTubeVideo}
from IPython.display import Image, Audio, YouTubeVideo

# %%
#@markdown 🔄 Making functions: etts('text'), ktts('text'), btts('text)
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def etts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "us",
                    slow = True)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def ktts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "ko",
                    slow = False)
  
  gtts_object.save("K-audio.mp3")
  return Audio("K-audio.mp3")

def btts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "co.uk",
                    slow = True)
  
  gtts_object.save("B-audio.mp3")
  return Audio("B-audio.mp3")

# %% [markdown]
# # [1] Korean vs. English vowels: [ a ] vs. [ ɑ ]

# %%
#@markdown Korean accent:
Spelling = "1. Spelling 'o'" #@param = ["1. Spelling 'o'","2. Spelling 'a'"]
pn = Spelling.split('. ')
pn = int(pn[0]) -1

wordlist = ["캅, cod, lock, comedy, contrary, company, copy, 옥슨, option, on, odd, honest, 숍 또는 샵, rocket, block, cot, top, fox, 스포트라이트, 오페라, 팔로우, constitution",
         "father, arm, want, wallet, dark, wasp, watch, March"]

wlist = wordlist[pn]

if pn == 0:
  txt = "제가 스펠링 'o'가 포함된 단어들을 말해보겠습니다. 몇 개의 다른 모음으로 말하는지 체크해 보세요. " + wlist

elif pn == 1:
  txt = "제가 스펠링 'a'가 포함된 단어들을 말해보겠습니다. 몇 개의 다른 모음으로 말하는지 체크해 보세요. " + wlist
ktts(txt)
Audio("K-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown English:

Spelling = "2. Spelling 'a'" #@param = ["1. Spelling 'o'","2. Spelling 'a'"]
pn = Spelling.split('. ')
pn = int(pn[0]) -1

wordlist = ["cop, cod, lock, comedy, contrary, company, copy, oxen, option, on, odd, honest, shop, rocket, block, cot, top, fox, spot, opera, follow, constitution",
         "father, arm, want, wallet, dark, wasp, watch, March"]

wlist = wordlist[pn]

if pn == 0:
  txt = "Let me say 'o' spelling included words. " + wlist

elif pn == 1:
  txt = "Let me say 'A' spelling including words. " + wlist
etts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown 😜 Korean with English accent:
samples = "1" #@param = [1, 2, 3]

pn = int(samples) -1
sents = ["Oh no! o-noo loon sooyo il imneedah.", "oppa? 'O' nool bah pah yo?", "o-hoo 'A' maan-na-yo."]
txt = sents[pn]

etts(txt)
Audio("E-audio.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # [2] Read aloud

# %%
#@markdown Read aloud "US constitution"
text = """The Constitution of the United States is the supreme law of the United States of
America. The Constitution, originally comprising seven articles, delineates the
national frame of government. Its first three articles entrench the doctrine of the
separation of powers, whereby the federal government is divided into three
branches: the legislative, consisting of the bicameral Congress; the executive,
consisting of the President; and the judicial, consisting of the Supreme Court and other federal
courts. Articles Four, Five and Six entrench concepts of federalism, describing the rights and
responsibilities of state governments and of the states in relationship to the federal
government. Article Seven establishes the procedure subsequently used by the thirteen States
to ratify it."""

etts(text)
Audio("E-audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
