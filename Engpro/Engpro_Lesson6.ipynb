# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2023/blob/main/Engpro/Engpro_Lesson6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 6. Vowel pair 5: [ ʌ ] as in ‘but', [ ɔ ] as in 'bought', and [oʊ ] as in 'boat''

# %% [markdown]
# ## 📌 Setting ups

# %%
#@markdown 💠 Import libraries {Image, Audio, YouTubeVideo}
from IPython.display import Image, Audio, YouTubeVideo

# %%
#@markdown 🔄 Making functions: etts('text'), ktts('text'), btts('text)
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def etts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "us",
                    slow = True)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def ktts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "ko",
                    slow = False)
  
  gtts_object.save("K-audio.mp3")
  return Audio("K-audio.mp3")

def btts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "co.uk",
                    slow = True)
  
  gtts_object.save("B-audio.mp3")
  return Audio("B-audio.mp3")

def ctts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "ca",
                    slow = True)
  
  gtts_object.save("C-audio.mp3")
  return Audio("C-audio.mp3")

# %% [markdown]
# # Intro: listen and write down words as you hear:

# %%
#@markdown Korean accent:
Spelling = "1" #@param = [1, 2, 3, 4, 5]

pn = int(Spelling) -1

wordlist = ["but, bought, and boat",
         "cut, caught, and coat",
         "hull, hall, and hole",
         "colour, caller, and collar",
         "mull, mall, and mole"]

wlist = wordlist[pn]

txt = "제가 서로 다른 영어 단어 세 개를 말해볼게요." + " " + wlist

ktts(txt)
Audio("K-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown English accent:
Spelling = "5" #@param = [1, 2, 3, 4, 5]

pn = int(Spelling) -1

wordlist = ["boat, bought, and but",
         "cut, caught, and coat",
         "hull, hall, and hole",
         "colour, caller, and collar",
         "mull, mall, and mole"]

wlist = wordlist[pn]
txt = "Let me say three different English words. " + " " + wlist
etts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # [1] Korean vs. English vowels: [ ʌ ], [ ɔ ], and [ oʊ ]

# %% [markdown]
# # A. Warming up: [ ʌ ]

# %%
#

Positions = "1-At the beginning of words" #@param = ["1-At the beginning of words", "2-In the middle of words", "3-At the end of words"]

ps = Positions.split('-')
np = ps[0]
np = int(np) -1

wordlist = ["up, of, us, uncle, under, upper, onion, other, ugly",
            "lucky, hug, much, rough, does, come, trouble, done, nut, must, sun, son, some",
            "There is no word ending with this vowel in English."]

wlist = wordlist[np]
intro = ps[1] + ":" 
mytxt = intro + wlist + "." + "This is the end."
etts(mytxt)

Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # B. Warming up: [ ɔ ]

# %%
#

Positions = "1-At the beginning of words" #@param = ["1-At the beginning of words", "2-In the middle of words", "3-At the end of words"]

ps = Positions.split('-')
np = ps[0]
np = int(np) -1

wordlist = ["off, all, also, August, audience, ought, often, always",
            "boss, long, across, song, bought, caught, broad, taught, wrong, dog, toss, lawn, auto, auction, mall, call, fall, salt, stall.",
            "law, raw, jaw, straw, draw, flaw."]

wlist = wordlist[np]
intro = ps[1] + ":" 
mytxt = intro + wlist + "." + "This is the end."
etts(mytxt)

Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
#  # [2] Minimal pairs

# %%
Pairs = "6. dog, vs dug" #@param = ["1. but, bought, and boat", "2. cut, caught, and coat", "3. hull, hall, and hole", "4. scull, call, and coal", "5. mull, mall, and mole", "6. dog, vs dug", "7. dawn, vs done", "8. long, vs lung", "9. cough, vs cuff", "10. saw, vs so", "11. law, vs low", "12. tall, vs toll", "13. bald, vs bold", "14. color, caller and collar"]

pn = Pairs.split(". ")
n = pn[0]
p = int(pn[0]) - 1
pw = pn[1]

txt = "Number" + n + ":" + pw
etts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # [3] Listening

# %%
#@markdown Instruction:

text = "You'll be hearing two sentences. Circle one that contains a word with an open O vowel."
etts(text)
Audio("E-audio.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Example:

text = "(a) It's in the hall. (b) It's in the hole."
etts(text)
Audio("E-audio.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
questions = "5" #@param = [1,2,3,4,5]
qn = int(questions) -1

sents = ["A. It's in the hole. (b) It's in the hall. ",
        "A. I dropped the bowl. (b) I dropped the ball.", 
         "A. I said talk. (b) I said tuck.",
         "A. The stock is high. (b) The stalk is high.",
         "A. He sawed it. (b) He sewed it."]

txt = "Number " + questions + "! " + sents[qn]
etts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
