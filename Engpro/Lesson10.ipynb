# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2023/blob/main/Engpro/Lesson10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lession 10 Word stress in English

# %%
#@markdown 🔄 Install and import libraries
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio, Image

# %%
#@markdown 🔄 Making functions: etts('text'), ktts('text'), btts('text)
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def etts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "us",
                    slow = False)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def ktts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "ko",
                    slow = False)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def btts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "co.uk",
                    slow = False)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def ctts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "ca",
                    slow = False)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

# %% [markdown]
# Page 59

# %%
p1 = "1" #@param = [1,2,3,4,5]
n = int(p1)-1
prgs = ["In English, the stress pattern of a word is usually fixed. And it determines the pronunciation of that word with a specific meaning. This means that changing the stress pattern of a word may alter its meaning. However, when additional morphemes are added to a word, the stress position may shift to a different syllable. For example, the word 'economy' has the primary stress on the second syllable, whereas 'economic' has the primary stress on the third syllable. This shift in stress pattern occurs when the grammatical category of a word changes, such as in the case of the verb 'to record' and the noun 'record', or in compound words like 'greenhouse'.",
        "If you want to know the stress pattern of a particular word, you can check a dictionary. Most dictionaries indicate the stress pattern of a word with a symbol, such as a single quotation mark before the stressed syllable or an accent mark above a vowel. These stress marks can help you identify which syllable(s) are stressed in a word and how to pronounce it correctly.",
        "Knowing the stress pattern of English words is critical for correct pronunciation. Stressing the wrong syllable can confuse listeners and make your speech less intelligible. It's essential to practice stress placement in both individual words and phrases to improve your pronunciation skills. In the next lesson, we will explore how stress works in phrases and sentences to help you communicate more effectively.",
        "Stressed syllables in English words are typically longer in duration, louder in intensity, and often higher in pitch compared to the other unstressed syllables in the word. However, it's important to note that the pitch may not always be higher, and it should be adjusted to reflect the intended meaning of the word in the context of the sentence. By paying attention to stress patterns, duration, intensity, and pitch, you can improve your pronunciation skills and communicate more effectively in English.",
        "English words that have more than two syllables can have multiple stresses. In such cases, there are usually one or more primary or main stresses, as well as one or more secondary stresses. Primary stresses are typically the strongest and most prominent, while secondary stresses are weaker and less prominent than the primary stress. Understanding the placement of primary and secondary stresses in multi-syllabic words is important for correct pronunciation and effective communication in English."]

txt = prgs[n]
etts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #Practice

# %%
stress = "1st" #@param = ["1st","2nd","3rd"]
str = int(stress[0])
n=str-1
wlist = ["Stress on the 1st syllable. Accident, strawberry, seventy, personal, elephant, February, and salary.",
         "Stress on the 2nd syllable. Acceptance, vanilla, examine, translation, gorilla, December, and employer.",
         "Stress on the 3rd syllable. Accidental, absolute, seventeen, personnel, kangaroo, gasoline, and employee"]
txt = wlist[n]
etts(txt)
Audio("E-audio.mp3",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
