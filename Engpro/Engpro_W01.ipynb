# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2023/blob/main/Engpro/Engpro_W01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💦 **Engpro Week 01: Course overview and introduction**
#
# Table of contents:
#
# + Part I. Getting started
# + Part II. Course syllabus
# + Part III. Introduction
# + Part IV. What is good pronunciation

# %% [markdown]
# ---

# %% [markdown]
# ## Class **settings**

# %% [markdown]
# ### 🔵 Install & import modules

# %%
from IPython.display import YouTubeVideo, display, Audio, Image

# %%
import pandas as pd

# %% [markdown]
# ### 🔵 gTTS setting

# %%
#@markdown 🔄 Making functions: etts('text'), ktts('text')
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def etts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "us",
                    slow = True)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def ktts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "ko",
                    slow = False)
  
  gtts_object.save("K-audio.mp3")
  return Audio("K-audio.mp3")

# %% [markdown]
# # **Part I. Getting started with two questions**

# %% [markdown]
# ## 🔵 Q1. Confusing pronunciation?

# %% [markdown]
# [orally](https://www.dictionary.com/browse/oral) vs. [aurally](https://www.dictionary.com/browse/aural) in Dictionary.com

# %%
#@markdown 📒 Confusing vowels:
url = "https://github.com/MK316/images/raw/main/orally.png"
Image(url, width=800, height=400)

# %%
#@markdown 🎧Instruction:
text = "Oh, I said take the fish oil orally, and not aurally!"
etts(text)
Audio("E-audio.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Oakland (in California) vs. Auckland (in New Zealand)

# %%
#@markdown 📒 The two cities on the map:
url = "https://github.com/MK316/images/raw/main/engpromap1.png"
Image(url, width=600, height=500)

# %% [markdown]
# ## 🔵 Q2.How is human speaking possible?

# %%
#@markdown 🎧Instruction:
text = "Look at the diagram below and think about what it tells you. Find anything relevant to this course"
etts(text)
Audio("E-audio.mp3", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown 📒 Show diagram:
url = "https://github.com/MK316/images/raw/main/brain-sense.png"
Image(url, width = "600", height="500")

# %% [markdown]
# # **Part II. Course syllabus** & overview

# %% [markdown]
# ## 🔵 Syllabus (printed version)

# %%
#@markdown Install pdf2image
# %%capture
# !apt-get install poppler-utils
# !pip install pdf2image

# %% [markdown]
# [File location](https://github.com/MK316/Spring2023/raw/main/data/S23Syllabus_Engpro_topost.pdf) - to download

# %%
# %%capture
# !wget https://github.com/MK316/Spring2023/raw/main/data/S23Syllabus_Engpro_topost.pdf

# %%
#@markdown Read the syllabus file & display (pdf)
from pdf2image import convert_from_path, convert_from_bytes
from IPython.display import display, Image

images = convert_from_bytes(open('S23Syllabus_Engpro_topost.pdf', 'rb').read(), size=1080)
display(images[0])

# %% [markdown]
# A survey on our Attendance policy

# %% [markdown]
# https://forms.gle/yJkaLmNSQoyQ63a19

# %%
#@markdown Install {pyqrcode} 
# !pip install pyqrcode

import pyqrcode
from pyqrcode import QRCode

#@markdown Enter the link in the pop-up window (It'll save it and display a QR code)
s = input("Paste the link: ")

# Generate QR code
url = pyqrcode.create(s)

# Create and save the png file naming "myqr.png"
url.svg("myqrcode.svg", scale=10)

from IPython.display import SVG, display
def show_svg(file):
    display(SVG(file))

show_svg("myqrcode.svg")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 KB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyqrcode: filename=PyQRCode-1.2.1-py3-none-any.whl size=36245 sha256=9970516902092cd5ab475471f311952bcfa9ec16bb8c11067a224b6d2d3ab0e5
#   Stored in directory: /root/.cache/pip/wheels/e6/5e/b1/e42b38f43c94593ea57059de7e585c009c0f54e36e1a532992
# Successfully built pyqrcode
# ...
# Paste the link: https://forms.gle/yJkaLmNSQoyQ63a19

# %% [markdown]
# ## 🔵 Textbook (handout collection)

# %%
# Google drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Unmount drive
drive.flush_and_unmount()

# %% [markdown]
# ## 🔵 Overview of 5 Assignments (4 pts. each)

# %% [markdown]
# ### HW#1 Pre-recording of "18 sentences" (p.98) and a passage (p.99) for diagnosis

# %% [markdown]
# ### HW#2 TED talk selection: go to [TED](https://www.ted.com/talks)

# %% [markdown]
# ### HW#3 Practice with a pop song
#
# [youtube link](https://www.youtube.com/watch?v=RhfHed14cNc)

# %%
#@markdown 🎬 Hey Jude (by the Beatles, 1968)
from IPython.display import YouTubeVideo, display
video = YouTubeVideo("RhfHed14cNc", width=600, height="400")
display(video)

# %% [markdown]
# Lyrics [link](https://github.com/MK316/images/blob/main/heyjude.md)
#
# Sample: Hey Jude, don't make it bad.
# Take a sad song and make it better.
# Remember to let her into your heart,
# Then you can start to make it better.

# %%
#@markdown Create audio file for your text using {gTTS}:

language = "ko" #@param ["en","ko"]

mytext = input("Type text to create an audio:  ")

if language == "en":
  etts(mytext)
  myaudio = "E-audio.mp3"
elif language == "ko":
  ktts(mytext)
  myaudio = "K-audio.mp3"

print("="*50)
print("Your text: %s"%mytext)
print("="*50)
Audio(myaudio)

# %% [markdown]
# ### HW#4 TED script (edited version) to submit (Max. 2 pages)

# %% [markdown]
# ### HW#5 Diagnostic recording (TBA)

# %% [markdown]
# ### Midterm (8th week) - inclass exam
#
# [Oxford learners vocabulary 3K](https://github.com/MK316/applications/blob/main/Oxford3K.ipynb) - create audio file (Downloadable)

# %%
#@markdown sample questions:

question = "1" #@param = [1, 2, 3]

q = int(question)

if q == 1:
  ans = input("Choose a word that contains the same vowel as in 'cod': a. mode  b. now  c. top  d. cope  e. boy ")
  if ans == "c":
      print("Correct!")
  else:
      print("Incorrect :(")
elif q == 2:
  ans = input("Circle a word that contains the same vowel as in 'food': a. wood  b. would  c. cook  d. hood  e. suit ")
  if ans == "e":
    print("Correct!")
  else:
    print("Incorrect.")
elif q == 3:
  ans = input("Find a word whose main stress is identical with 'abstract(v.)': a. occur  b. awkward  c.mindset  d. sorrow  e.digest(n.) ")
  if ans == "a":
    print("Correct!")
  else:
    print("Incorrect.")
# Out:
# Choose a word that contains the same vowel as in 'cod': a. mode  b. now  c. top  d. cope  e. boy c
# Corrent!

# %%
answer_key = "1" #@param = [1,2]

if answer_key == "1":
  mytext = "A is mode.  B is now.  C is top.  D is cope.  E is boy. So, 'cod' and 'top' share the same vowel."

elif answer_key == "2":
  mytext = "A is wood.  B is would.  C is cook.  D is hood.  E is suit. Thus, 'food' and 'suit' share the same vowel."

etts(mytext)
Audio("E-audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Final presentation - 3.5 minutes' presentation (TED talk) and evaluation

# %%
#@markdown 🎬 Sample presenation
from IPython.display import YouTubeVideo, display
video = YouTubeVideo("0fWKCJctKlQ", width=600, height="400")
display(video)

# %% [markdown]
# # 🔵 Course material

# %% [markdown]
# ## [1] Homepage [MK316.github.io](https://MK316.github.io)
#
# https://github.com/MK316/Spring2023/tree/main/Engpro

# %% [markdown]
# ## [2] Workbook (printed)

# %% [markdown]
# # **Part III. Introduction**

# %% [markdown]
# ---

# %% [markdown]
# ## 🔵 [1] Understanding English sounds

# %% [markdown]
# Every language uses different sets of sounds (known as, inventories).

# %%
mytext = "Bin, pin, spin, sale, slow, and miss."
etts(mytext)
ktts(mytext)

Audio("K-audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio("E-audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Generate speech
#
# 1) My phone number is zero, four, three, six.
# 2) I said, 'zero, measure, magic'.
# 3) The vowels in 'beat' and 'bit' are not the same, right?

# %%
language = "ko" #@param = ["en", "ko"]

txt = input("Type text: ")

if language == "en":
  etts(txt)
  file = "E-audio.mp3"
elif language == "ko":
  ktts(txt)
  file= "K-audio.mp3"

Audio(file)
# Out:
# Type text: My phone number is zero, four, three, six.
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 🔵 [2] What to focus
#
# + How to make individual sounds, **(articulation)**
# + how to connect the sounds in words, **(rules and principles)**
# + how to change/manipulate our tones of speaking in order to appropriately communicate with others. **(stres, accent, rhythm, and intonation)**

# %% [markdown]
# ## 🔵 [3] International Phonetic Alphabet (IPA) and English dictionaries

# %% [markdown]
# + International Phonetic Association [weblink](https://www.internationalphoneticassociation.org/)
# + [IPA chart](https://www.ipachart.com/)

# %%
url = "https://github.com/MK316/Spring2023/raw/main/Engpro/data/ipa_website.png"
Image(url, width="600", height="500")

# %% [markdown]
# spelling and sounds

# %%
#@markdown Sample: Korean names
etts("Choi, Min-Jeong.")
Audio("E-audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# wordlist: sigh, laugh, cake, so, pod, who, hood, cool, cook, scene, seen, sin, been
#
# + Type IPA online [web link](https://ipa.typeit.org/)
#
# ## i  ɪ  ɛ  æ  u  ʊ  ɔ  ɑ  ʌ  ə  aɪ  eɪ   ɔɪ   oʊ  aʊ

# %%
#@markdown 😉 **[DIY]** Number of letters and syllables, and Identify the vowel.
wlist = input("Type wordlist: ")

df = pd.DataFrame()
words = wlist.split(", ")
wn = len(words)
chars = []
sylls = []
vowels = []

for i in range(0,wn):
  w = words[i]
  char = input("How many letters in %s: "%w)
  chars.append(char)
  syll = input("How many syllables in %s: "%w)
  sylls.append(syll)
  vowel = input("What is the vowel in %s: "%w)
  vowels.append(vowel)
  print("="*50)

df['Words'] = words
df['Characters'] = chars
df['Num_of_Syllables'] = sylls
df['Vowel'] = vowels

save = input("Save the result as a file? (y or n)")
from google.colab import files

if save == "y":
  fn = input("File name: e.g., output.csv ")
  df.to_csv(fn, encoding = 'utf-8-sig') 
  files.download(fn)
elif save == "n":
  print("Okay, I'll just display it here.")
else:
  print("Try again: run the cell again.")

df
# Out:
# Type wordlist: psycho
# How many letters in psycho: 6
# How many syllables in psycho: 1
# What is the vowel in psycho: aɪ
# ...
# Save the result as a file? (y or n)y
# File name: e.g., output.csv sample.csv
#     Words Characters Num_of_Syllables Vowel
# 0  psycho          6                1    aɪ

# %% [markdown]
# # **Part IV. What is good pronunciation?**
# ---

# %% [markdown]
# ## 🔵 [1] How's your Korean?

# %%
#@markdown 💠 Information in the Digital Age (Slide #9)
from IPython.display import Image

pages = "6" #@param = ["1", "2", "3", "4", "5", "6"]
adds = ['https://github.com/MK316/images/raw/main/goodpron01.png',
        'https://github.com/MK316/images/raw/main/goodpron02.png',
        'https://github.com/MK316/images/raw/main/goodpron03.png',
        'https://github.com/MK316/images/raw/main/googpron04.png',
        'https://github.com/MK316/images/raw/main/goodpron05.png',
        'https://github.com/MK316/images/raw/main/goodpron06.png']
if pages == "1":
  add = adds[0]
elif pages == "2":
  add = adds[1]
elif pages == "3":
  add = adds[2]
elif pages == "4":
  add = adds[3]
elif pages == "5":
  add = adds[4]
elif pages == "6":
  add = adds[5]
  
Image(url=add, width=600, height=400)
# Out:
# <img src="https://github.com/MK316/images/raw/main/goodpron06.png" width="600" height="400"/>

# %%
#@markdown 🎧 Audio What is good diction? (by chatGPT)
txt = "Good diction refers to the clarity and precision with which a person speaks or writes. It encompasses aspects such as pronunciation, enunciation, and word choice. For a future English teacher, good diction is important because it sets an example for students and helps to create a positive learning environment. Good diction can help students understand what is being taught more easily, and it can also help to establish the teacher as an authority on the subject. Additionally, good diction can help to prevent misunderstandings and confusion in the classroom, ensuring that the students receive the correct information and guidance."
etts(txt)
Audio("E-audio.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 🔵 [2] Accuracy, Intelligibility, and comprehensibility

# %% [markdown]
# + **Accuracy** of speech refers to the **correctness of pronunciation, grammar, and vocabulary** in a speaker's language use. It measures adherence to standard norms and is important for effective communication and being understood.
# + **Intelligibility** of speech refers to the **clarity of a speaker's words and their ability to be understood** by listeners. It is concerned with effective communication, not just language accuracy.
# + **Comprehensibility** is the **ease of understanding** a speaker's message, considering context, background, and language use. It evaluates the overall communication process, including understanding of the speaker's intent, not just speech clarity. It is broader than intelligibility, which only focuses on pronunciation and articulation.

# %% [markdown]
# ### Accuracy

# %%
#@markdown 🎬 German Coastguard ("We are Sinking.")
from IPython.display import YouTubeVideo, display
video = YouTubeVideo("7C-vYY3SBDE", width=600, height="400")
display(video)

# %% [markdown]
# Accents

# %%
#@markdown 🎬 French accent of English (Lily-Rose Depp teaches you a French Accent")
from IPython.display import YouTubeVideo, display
video = YouTubeVideo("at_1INOoKps", width=600, height="400")
display(video)

# %% [markdown]
# ## 🔵 [3] Clarity for good diction. Why?

# %% [markdown]
# **Good diction** in speech is characterized by **clear and precise articulation, correct pronunciation, and appropriate word selection** that effectively conveys the speaker's intended meaning.

# %% [markdown]
# # The end
# ---
