# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2023/blob/main/Engpro/Engpro_Lesson7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 7. Vowel pair 6: diphthong vowels in English

# %% [markdown]
# ## 📌 Setting ups

# %%
#@markdown 💠 Import libraries {Image, Audio, YouTubeVideo}
from IPython.display import Image, Audio, YouTubeVideo

# %%
#@markdown 🔄 Making functions: etts('text'), ktts('text'), btts('text)
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def etts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "us",
                    slow = True)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def ktts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "ko",
                    slow = False)
  
  gtts_object.save("K-audio.mp3")
  return Audio("K-audio.mp3")

def btts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "co.uk",
                    slow = True)
  
  gtts_object.save("B-audio.mp3")
  return Audio("B-audio.mp3")

def ctts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "ca",
                    slow = True)
  
  gtts_object.save("C-audio.mp3")
  return Audio("C-audio.mp3")

# %% [markdown]
# # Introduction: Accents
#
# ##Experience different dialects and accents
#
#  e.g., Koreanized English words

# %%
#@markdown Korean vs. English ways to pronounce words
Words = "2" #@param = [1, 2, 3, 4, 5]
Language = "English" #@param = ["Korean", "English"]

wn = int(Words) -1
klist = ["토이스토리", "부탄가스", "로그온", "노트북", "프라이드 치킨"]
elist = ["Toy story.", "Butane gas.", "Log on.", "Notebook.","Fried chicken."]

if Language == "Korean":
  txt = "오키. 한국어로" + klist[wn] + " 라고 합니다."
  ktts(txt)
  file = "K-audio.mp3"
elif Language == "English":
  txt = "Okay! In English, we say " + elist[wn] + "."
  etts(txt)
  file = "E-audio.mp3"

Audio(file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Foreign accents:
Words = "2" #@param = [1, 2, 3, 4, 5]
Language = "fr" #@param = ["en","fr","zh-CN","ja", "es"]
pn = int(Words) -1

wordlist = ["Toy story.", "Butane gas.", "Log on.", "Notebook.","Fried chicken."]
wlist = wordlist[pn]
txt = "In my country, people may pronounce this word, like, " + " " + wlist

if Language == "en":
  def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                     lang = "en",
                    slow = False) 
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")
else:
  def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                       lang = Language, slow = False)
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")

tts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown You can type words here:
Language = "fr" #@param = ["en","fr","zh-CN","ja", "es","ko"]
pn = int(Words) -1

words = input("Type text: ")

txt = "In my country, people may pronounce this word, like, " + " " + words


def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                       lang = Language, slow = False)
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")

tts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
# Type text: toy story
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # [1] Korean vs. English accents: [eɪ, aɪ, aʊ, oʊ, ɔɪ]

# %%
#@markdown Korean accent:
words = "2" #@param = [1, 2, 3, 4, 5]

pn = int(words) -1

wordlist = ["game, may, say, hey, name",
         "night, hi, bye, sigh, guy",
         "how, now, hour, sour, loud",
         "don't, no, so, cold, hold",
         "boy, oil, noise, choice, soil"]

wlist = wordlist[pn]

txt = "제가 같은 모음이 들어가는 영어 단어 다섯 개를 말해볼게요." + " " + wlist

ktts(txt)
Audio("K-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown English accent:
Spelling = "1" #@param = [1, 2, 3, 4, 5]
Language = "zh-CN" #@param = ["en","fr","zh-CN","es"]
Dialect = "com.au" #@param = ["com.au","co.uk","us","ca","co.in","ie", "co.za"]
pn = int(Spelling) -1

wordlist = ["game, may, say, hey, name",
         "night, hi, bye, sigh, guy",
         "how, now, hour, sour, loud",
         "don't, no, so, cold, hold",
         "boy, oil, noise, choice, soil"]

wlist = wordlist[pn]
txt = "Let me say five different English words. Listen carefully. " + " " + wlist

if Language == "en":
  def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = Dialect,
                    slow = False) 
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")
else:
  def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                       lang = Language, slow = False)
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")

tts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
# WARNING:gtts.lang:'zh-CN' has been deprecated, falling back to 'zh-CN'. This fallback will be removed in a future version.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # [2] Diphthong vowels in sentences

# %% [markdown]
# gTTS language options

# %%
import gtts.lang
print(gtts.lang.tts_langs())
# Out:
# {'af': 'Afrikaans', 'ar': 'Arabic', 'bg': 'Bulgarian', 'bn': 'Bengali', 'bs': 'Bosnian', 'ca': 'Catalan', 'cs': 'Czech', 'da': 'Danish', 'de': 'German', 'el': 'Greek', 'en': 'English', 'es': 'Spanish', 'et': 'Estonian', 'fi': 'Finnish', 'fr': 'French', 'gu': 'Gujarati', 'hi': 'Hindi', 'hr': 'Croatian', 'hu': 'Hungarian', 'id': 'Indonesian', 'is': 'Icelandic', 'it': 'Italian', 'iw': 'Hebrew', 'ja': 'Japanese', 'jw': 'Javanese', 'km': 'Khmer', 'kn': 'Kannada', 'ko': 'Korean', 'la': 'Latin', 'lv': 'Latvian', 'ml': 'Malayalam', 'mr': 'Marathi', 'ms': 'Malay', 'my': 'Myanmar (Burmese)', 'ne': 'Nepali', 'nl': 'Dutch', 'no': 'Norwegian', 'pl': 'Polish', 'pt': 'Portuguese', 'ro': 'Romanian', 'ru': 'Russian', 'si': 'Sinhala', 'sk': 'Slovak', 'sq': 'Albanian', 'sr': 'Serbian', 'su': 'Sundanese', 'sv': 'Swedish', 'sw': 'Swahili', 'ta': 'Tamil', 'te': 'Telugu', 'th': 'Thai', 'tl': 'Filipino', 'tr': 'Turkish', 'uk': 'Ukrainian', 'ur': 'Urdu', 'vi': 'Vietnamese', 'zh-CN': 'Chinese (Simplified)', '
# ...

# %%
Items = "1" #@param = [1, 2, 3, 4, 5]
Language = "ja" #@param = ["en","fr","zh-CN","ja","es"]
#@markdown Dialect options only for English
Dialect = "com.au" #@param = ["com.au","co.uk","us","ca","co.in","ie", "co.za"]
numbers = ["one", "two","three","four","five"]
np = int(Items) -1

wordlist = ["Oh, really? I can't believe it.",
            "So, we are finished! You guys did a great job!",
            "Please don't tell him. He's going to cry.",
            "It's very cold in here. Could you open the window please?",
            "You don't have to. It's upto you."]

if Language == "en":
  def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = Dialect,
                    slow = False) 
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")
else:
  def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                       lang = Language, slow = False)
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")


wlist = wordlist[np]
intro = "Number " + numbers[np] + "!" 
mytxt = intro + wlist
tts(mytxt)

Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # [3] Warming-ups

# %% [markdown]
# ## A.  Warming up:  [ eɪ ]

# %%
#

Positions = "3-At the end of words" #@param = ["1-At the beginning of words", "2-In the middle of words", "3-At the end of words"]

ps = Positions.split('-')
np = ps[0]
np = int(np) -1

wordlist = ["ate, able, aim, eight, age, April, ache, apron",
            "rain, date, place, paint, came, paper, same, break",
            "way, day, say, weigh, May, they, lay, obey."]

wlist = wordlist[np]
intro = ps[1] + ":" 
mytxt = intro + wlist + "." + "This is the end."
etts(mytxt)

Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## B.  Warming up:  [ aɪ ]

# %%
#

Positions = "3-At the end of words" #@param = ["1-At the beginning of words", "2-In the middle of words", "3-At the end of words"]

ps = Positions.split('-')
np = ps[0]
np = int(np) -1

wordlist = ["eye, I, ice, idea, aisle, icon, ivory",
            "bite, byte, fight, kind, mind, sign, while, height",
            "by, buy, lie, lye, sigh, die, dye, try, deny, tie."]

wlist = wordlist[np]
intro = ps[1] + ":" 
mytxt = intro + wlist + "." + "This is the end."
etts(mytxt)

Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## C.  Warming up:  [ aʊ ]

# %%
#

Positions = "3-At the end of words" #@param = ["1-At the beginning of words", "2-In the middle of words", "3-At the end of words"]

ps = Positions.split('-')
np = ps[0]
np = int(np) -1

wordlist = ["owl, out, hour, outlet, ounce, ourselves",
            "loud, mouse, pronounce, down, crowd, flower, scout",
            "cow, how, now, allow, plough."]

wlist = wordlist[np]
intro = ps[1] + ":" 
mytxt = intro + wlist + "." + "This is the end."
etts(mytxt)

Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## D.  Warming up:  [ oʊ ]

# %%
#

Positions = "3-At the end of words" #@param = ["1-At the beginning of words", "2-In the middle of words", "3-At the end of words"]

ps = Positions.split('-')
np = ps[0]
np = int(np) -1

wordlist = ["own, old, over, open, oat, ocean, only",
            "boat, spoke, both, known, don't, nose",
            "go, so, no, hello, snow, dough."]

wlist = wordlist[np]
intro = ps[1] + ":" 
mytxt = intro + wlist + "." + "This is the end."
etts(mytxt)

Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## E.  Warming up:  [ ɔɪ ]

# %%
#

Positions = "3-At the end of words" #@param = ["1-At the beginning of words", "2-In the middle of words", "3-At the end of words"]

ps = Positions.split('-')
np = ps[0]
np = int(np) -1

wordlist = ["oil, oyster, oily, oink, ointmemt",
            "join, foil, noise, boil, poison, choice, avoid, coin",
            "toy, boy, enjoy, decoy, annoy, destroy."]

wlist = wordlist[np]
intro = ps[1] + ":" 
mytxt = intro + wlist + "." + "This is the end."
etts(mytxt)

Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
#  # [4] More Practice: Experience different dialects and accents
#
#  e.g., Koreanized English words

# %%
#@markdown Korean vs. English ways to pronounce words
Words = "2" #@param = [1, 2, 3, 4, 5]
Language = "English" #@param = ["Korean", "English"]

wn = int(Words) -1
klist = ["토이스토리", "부탄가스", "로그온", "노트북", "프라이드 치킨"]
elist = ["Toy story.", "Butane gas.", "Log on.", "Notebook.","Fried chicken."]

if Language == "Korean":
  txt = "오키. 한국어로" + klist[wn] + " 라고 합니다."
  ktts(txt)
  file = "K-audio.mp3"
elif Language == "English":
  txt = "Okay! In English, we say " + elist[wn] + "."
  etts(txt)
  file = "E-audio.mp3"

Audio(file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Foreign accents:
Words = "2" #@param = [1, 2, 3, 4, 5]
Language = "fr" #@param = ["en","fr","zh-CN","ja", "es"]
pn = int(Words) -1

wordlist = ["Toy story.", "Butane gas.", "Log on.", "Notebook.","Fried chicken."]
wlist = wordlist[pn]
txt = "In my country, people may pronounce this word, like, " + " " + wlist

if Language == "en":
  def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                     lang = "en",
                    slow = False) 
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")
else:
  def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                       lang = Language, slow = False)
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")

tts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown You can type words here:
Language = "fr" #@param = ["en","fr","zh-CN","ja", "es","ko"]
pn = int(Words) -1

words = input("Type text: ")

txt = "In my country, people may pronounce this word, like, " + " " + words


def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                       lang = Language, slow = False)
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")

tts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
# Type text: toy story
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
