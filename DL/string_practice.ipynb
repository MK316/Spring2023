# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2023/blob/main/DL/string_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 🎯 문자열에 관한 여러가지 함수
#   1. 문자열에서 특정 위치/구간의 문자 얻기
#   2. 문자열에서 홀수/짝수 위치 문자 따로 얻기
#   3. 문자열을 거꾸로 만들기
#   4. 문자열 합치기
#   5. 문자열 반복하기
#   6. 문자열 확인하기
#   7. 문자열 길이 확인하기
#     - unicode
#       - codeline: len(variable name)
#     - bite
#       - codeline: len.encode(variable name)
#   8. 문자열이 알파벳인지 검사
#     - codeline: variable 1 = varialbe0.isalpha() period.isalpha function 사용하기
#
#  PB: 문자열에 대한 코드를 그대로 다시 돌려보았는데, str object 를 못찬는다고 print () 함수에서 일괄적으로 에러가 남. 오늘은 전체적으로 print () 함수에 str object 에러가 나는 것 같음. (as of April 2, 2023)

# %%
#문자열에서 특정 위치의 문자 얻기; 문자열에서 지정 구간 문자 얻기 Part1

txt1='This rat named Arthur'

print(txt1[1])
print(txt1[7])
print(txt1[-3])

print(txt1[1:]) #(나의 해석)두번째 요소부터 끝까지
print(txt1[3:7]) #(나의 해석)네번째 요소부터 일곱번째 요소까지  
print(txt1[:-5]) #처음부터 끝 5번째 요소들까지 제외한 것 

print(txt1[::2])
print(txt1[1::2])
print(txt1[1:2])
# Out:
# h
# t
# h
# his rat named Arthur
# s ra
# This rat named A
# Ti a ae rhr
# hsrtnmdAtu
# h

# %%
#문자열에서 지정 구간 문자 얻기 Part2
txt2='Elizabeth'

for i in range(len(txt2)):
#for i in range(txt2): 를 사용하면 아래 [:i+1] 파트에 오류가 남
  print (txt2[:i+1])
# Out:
# E
# El
# Eli
# Eliz
# Eliza
# Elizab
# Elizabe
# Elizabet
# Elizabeth

# %%
txt3='산뫼토뫼끼뫼' 
print(txt3[::2])
print(txt3[1::2])

txt4='산토끼'

def reverse(x, y, z):
  return z, y, x           #return 값은 할당기호 (=) 없이 reverse 함수 인자를 바로 입력한다. 아니면 error message 뜬다.

r1,r2,r3 = reverse('산','토','끼')
print (r1,r2,r3)

ret = txt4[::-1]
print(ret)
# Out:
# 산토끼
# 뫼뫼뫼
# 끼 토 산
# 끼토산

# %%
# My exercise 
txt = '토끼야어디가?'
res1=txt[::2]
print (res1)

res2=txt[1::2]
print(res2)

def reverse(x,y):
  return x, y

res3=reverse(res1, res2)
print(res3)

res4 = txt[::-1]
print(res4)

for i in range(len(txt)):
  print(txt[:i+1])
# Out:
# 토야디?
# 끼어가
# ('토야디?', '끼어가')
# ?가디어야끼토
# 토
# 토끼
# 토끼야
# 토끼야어
# 토끼야어디
# 토끼야어디가
# 토끼야어디가?

# %%
name = input('입력할 파일 이름은 무엇입니까?:')
result = name + '.txt'
print ('입력한 파일 이름과 그 포맷은 <'+result+'> 입니다.')
# Out:
# 입력할 파일 이름은 무엇입니까?:test
# 입력한 파일 이름과 그 포맷은 <test.txt> 입니다.

# %%
#문자열 합치기

title = input('파일명을 입력하세요.:')
titled = title + '.jpg'
print ('저장된 파일은 <'+titled+'> 입니다.')
# Out:
# 파일명을 입력하세요.:test
# 저장된 파일은 <test.jpg> 입니다.

# %%
#문자열 합치기 & 문자열 반복하기
word1 = '우리나라 축구 대표팀'
word2 = '화이팅'
phrase1 = word1 + ' ' +  word2*10 + '~'*3 #Space 확보를 위해서는 quotes 안에 Space 를 확보해 놓으면 됨
phrase2 = word1 + ', ' +  word2*10 + '~'*3
print(phrase1)
# Out:
# 우리나라 축구 대표팀 화이팅화이팅화이팅화이팅화이팅화이팅화이팅화이팅화이팅화이팅~~~

# %%
# 문자 or 문자열 확인하기

txt1 = input('임의의 문장을 입력하세요:')

if 'c' in txt1:
  print('Yes')
else:
  print('No')

if 'are' in txt1:
  print ('Yes')
else:
  print('No')
# Out:
# 임의의 문장을 입력하세요:안녕하세요
# No
# No

# %%
#문자열 길이 확인하기

txt2 = input('Type in your sentence.')

mslength = len(txt2)

print('당신이 입력한 문자의 길이는 <%d> 입니다.' %mslength)
# Out:
# Type in your sentence.안녕하세요
# 당신이 입력한 문자의 길이는 <5> 입니다.

# %%
#문자열이 알파벳만으로 구성되었는지 검사 isalpha(variable name)

txt1 = 'hi'
txt2 = '안녕'
txt3 = 'Hi Emma!'
txt4 = 'where2go'

ret1 = txt1.isalpha()
ret2 = txt2.isalpha()
ret3 = txt3.isalpha()
ret4 = txt4.isalpha()

print(ret1)
print(ret2)
print(ret3)
print(ret4)
# Out:
# True
# True
# False
# False
