# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2023/blob/main/DL/DL_assign02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # ⏰ Todo: This is an individual assignment by Apr.5
#
# - Create a blog page on your github

# %% [markdown]
# # [1] Learn about ChatGPT (from OpenAI)
#
# + [OpenAI Web link](https://chat.openai.com)
# + **OpenAI** is an AI research laboratory focused on creating safe and beneficial AI to positively impact humanity. It conducts research in areas like natural language processing and robotics, and promotes AI safety and ethics.
# +  Video for individuals at home (from ABC News: Interview with OpenAI CEP, CTO: 21m 37s) (1) [Youtube link](https://www.youtube.com/watch?v=540vzMlf-54), (2) [chatGPT 4 introduction on Youtube](https://youtu.be/--khbXchTeE)

# %%
#@markdown Watch Video (from CNBC News: Why OpenAI's ChatGPT is such a big deal.) [12m 52s]
video = YouTubeVideo("pOmpqdlVCoo", width=600)
display(video)

# %% [markdown]
# + [Transcript of the video in the above](https://github.com/MK316/Spring2023/blob/main/DL/cnbc.md) for your reference

# %% [markdown]
# + [For your reference] Microsoft office meets chatGPT (individuals at home) [Video in Korean](https://www.youtube.com/watch?v=wKTx_3da5Qs) for your further reference

# %% [markdown]
# # [2] After watching the video above, complete the following quiz.
#
# **Note** You are allowed to use chatGPT to do this activity
#
# [Quiz link](https://forms.gle/MxRkoLuPpKfs6aGo8)

# %% [markdown]
# # [3] Create an md file on your Github
#
# **🌿Instructions:** (You have a video to watch below to refer to for this assignment)
#
# 1. Create an md file (file name: e.g., G6_0329.md) in your DL repository on Github
#
# 2. Create a Q&A content answering the following questions: show each question and your answer on the same page (**Note**: All answers should be composed in English.)
#
#
#
# > **A. What interesting points did you discover about ChatGPT through today's group activity?**
#
#
#
# > **B.  As an English learner, how do you think ChatGPT can help you with your English studies?**
#
# > **C. As a future English teacher, how do you think ChatGPT can help you with your English classroom in the future?**
#
# * If you want Emoji icons, refer to [here](https://gist.github.com/rxaviers/7360908)
#
# * If you want some text editing, refer to [here](https://docs.github.com/en/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax): Basics for Markdown language

# %%
#@markdown Watch Video first (7m): how to create an md file on Github
#@markdown 💠 Import libraries {Image, Audio, YouTubeVideo}
from IPython.display import YouTubeVideo
video = YouTubeVideo("x0vtv7UmejM", width=600)
display(video)
