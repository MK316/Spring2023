# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2023/blob/main/DL/DLW04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌳 **Digital Literacy & English Education** (Week 04):
# # Digital Communication and Collaboration 1:
#
#
# Table of contents
#
# * Social media and online communities
# * Collaboration tools and virtual meetings

# %% [markdown]
# The Contact - 1997

# %% [markdown]
# # [1] Digital life 30 years ago

# %%
#@markdown 🔄 Import IPython display
# %%capture
from IPython.display import YouTubeVideo, display, Image

# %%
#@markdown Scenes from "The Contact" (1997)
img = "3" #@param = [0, 1,2,3,4,5]

if img == "0":
  url = "https://github.com/MK316/images/raw/main/0.png"
elif img == "1":
  url = "https://github.com/MK316/images/raw/main/1.png"
elif img == "2":
  url = "https://github.com/MK316/images/raw/main/2.png"
elif img == "3":
  url = "https://github.com/MK316/images/raw/main/3.png"
elif img == "4":
  url = "https://github.com/MK316/images/raw/main/4.png"
elif img == "5":
  url = "https://github.com/MK316/images/raw/main/5.png"
Image(url, width = "800")

# %% [markdown]
# [Youtube link for the OST](https://www.youtube.com/watch?v=bRlicxf8iJQ)

# %%
#@markdown OST #1 A Lover's Concerto
from IPython.display import YouTubeVideo, display
video = YouTubeVideo("bRlicxf8iJQ", width=500)
display(video)

# %% [markdown]
# [Youtube link for the OST](https://www.youtube.com/watch?v=aNSH8OdHx2A)

# %%
#@markdown OST #2 Pale Blue Eyes
from IPython.display import YouTubeVideo, display
video = YouTubeVideo("aNSH8OdHx2A", width=500)
display(video)

# %% [markdown]
# # [2] Digital Life in 2023: Exploration

# %% [markdown]
# ## A. chatGPT
#
# [pyChatGPT from https://github.com/terry3041/pyChatGPT](https://github.com/terry3041/pyChatGPT)
#
# Use web browser instead.

# %%
#@markdown 1) Installation
# %%capture
# !apt install chromium-browser xvfb
# !pip install -U selenium_profiles pyChatGPT

from selenium_profiles.utils.installer import install_chromedriver
install_chromedriver

# %%
from pyChatGPT import ChatGPT
from pprint import pprint
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# How to get your session token:
#
# 1. log in to https://chat.openai.com/chat
# 2. right click and choose inspect
# 3. go to Applications > Storage > cookies > _secure-next-auth.session-token
# 4. copy the value in __secure-next-auth.session-token

# %%
session_token = "eyJhbGciOiJkaXIiLCJlbmMiOiJBMjU2R0NNIn0..HVZFyw8X18x6xAXM.B-DV3Ksi2AGvxwGwJSjJ0kQ4l-ZFwIaswiuyddhXkaXbfGl9qkTHirPH1SgS6nYozvLr2wfYXc5RTLyRv_lCW4BRJwHoPuMP00sE9AUT7mkE-F0_vsvCHJzT9rMZhfcX4SXL0occ1yDsNdUTXP_mq4c7U1iNZ8xWZ3l-9DxcoVB4yasOE-gqp-ZCowIEv9xOHQfQG5NtNENt-dcuSCGzF3hAPoafbTeZ1zxXffW2FduCzrFkIssbT2TWQcwQv7Wb3KywNa5DkRoxYL1iQJwRG7dZUmSIC8kwbXDhjia2Wch6MWUkQoxFAE4R_7KOXWx4bOFYMPHuRMPHY1qY-Of2C7Z3R7sFo6ppTVJiZWEIIH0cXQNa-v_VyKYT71_-4wfTwOl2_eNmYxzNdM1HZsn7P11jh5Cl2bF12EBkLV-r1D3kDOfNgi7NhnbVB06pM1uWSy1UgPMb8wwekQgieYF-NWZSye2DU0_LsdgBUcI1ed5uaggn7YQ3PbMC33RC_9KVX77OKc1ASeI4AFvYk2LbVqwQ61zofNtekEPfIUS2kFlfuE-gCtvjVjkcTglKWXFb
WHvDm8IMo84jkUKzzBNjjP6Tc5mp86OkfFvkN5xTfSVKi8SXwIR5lIVJ2ye5Gem6wDwPZb6Mi_rzFDrmcLqmTnlACAec4p2YJCQfoWiYKRDBCiP9m7Ok1ekIow5xRvCVuepJczrgaCqfl0ipNGpYH2ImtLho5dLJ3VwUWR1LNUmUyD2ffM2Bk7zoqJ2RNZRy8fEW4a0WaiMnMoL4hf9UGzN87qsd4FDBG_rMlRhGrjudLK0V9n3n3zOMtFkI5VGre1en-CdZCfJpVqUe3ulEAe9DjbQb4VVZC7IS_EjG4eAG80hSUr6HNW12VGPRl2fl-KFguSCCw0HvvB9mqet9OOlKQTViasDIcSZwBZA8D0QSqyGhd2O2g9bdegiPoj4DslqQ2Fz5uAVxCiZ-F0PHxLS8oZTDeiF6rrNUm8soYKTaqYRCK6gI_nkkEDHlJ5W.dJwRYG5WC0Q7lsaq6mAVmw"

# %%
def getChatGPTResponse(message):
  model = ChatGPT(session_token)
  resp = model.send_message(message)
  return (resp['message'])

# %%
message = "What is Deep Learning?"
response=getChatGPTResponse(message)

print("[INFO] Response received")
# Out:
# DEBUG:pyChatGPT:Initializing browser...
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-10-97ce6e11c37b> in <module>
#       1 message = "What is Deep Learning?"
# ----> 2 response=getChatGPTResponse(message)
#       3
#       4 print("[INFO] Response received")
#
# <ipython-input-7-0c2017f3e9f4> in getChatGPTResponse(message)
#       1 def getChatGPTResponse(message):
# ----> 2   model = ChatGPT(session_token)
#       3   resp = model.send_message(message)
#       4   return (resp['message'])
#
# /usr/local/lib/python3.8/dist-packages/pyChatGPT/pyChatGPT.py in __init__(self, session_token, conversation_id, auth_type, email, password, login_cookies_path, captcha_solver, solver_apikey, proxy, chrome_args, moderation, verbose)
#     124             os.environ['PATH'] += os.pathsep + ffdl.ffmpeg_dir
#     125
# --> 126         self.__init_browser()
# ...

# %%
pprint(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-30dc12e54b9c> in <module>
# ----> 1 pprint(response)
#
# NameError: name 'response' is not defined

# %% [markdown]
# ## B. openAI

# %% [markdown]
# ### setup gtts for speech

# %%
#@markdown 1) Install and import modules
# %%capture
# !pip install gtts
from gtts import gTTS
from IPython.display import Audio, display

# %%
#@markdown 2) Define tts(text)

def tts(txt):
  tts = gTTS(txt, lang='en')
  tts.save("sample.mp3")
  return Audio("/content/sample.mp3")

# %%
#@markdown 3) Getting audio and display

mytext = input("Type text: ")
tts(mytext)
# Out:
# Type text: This is a test sentence.
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Q & As

# %%
#@markdown Q1: "What is openAI?"

mytext = "OpenAI is a research organization dedicated to promoting and developing friendly AI in a responsible way. It was founded in 2015 by Elon Musk, Sam Altman, Greg Brockman, Ilya Sutskever, and Wojciech Zaremba with the goal of ensuring that artificial intelligence benefits humanity as a whole. OpenAI conducts research in a wide range of areas related to AI, including machine learning, robotics, and natural language processing, and also provides open-source tools and resources for the AI community. The organization aims to advance AI in a way that is safe, transparent, and beneficial for society, and to promote a future in which AI is aligned with human values and well-being."
print(mytext)
tts(mytext)
# Out:
# OpenAI is a research organization dedicated to promoting and developing friendly AI in a responsible way. It was founded in 2015 by Elon Musk, Sam Altman, Greg Brockman, Ilya Sutskever, and Wojciech Zaremba with the goal of ensuring that artificial intelligence benefits humanity as a whole. OpenAI conducts research in a wide range of areas related to AI, including machine learning, robotics, and natural language processing, and also provides open-source tools and resources for the AI community. The organization aims to advance AI in a way that is safe, transparent, and beneficial for society, and to promote a future in which AI is aligned with human values and well-being.
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Q2: "What is chatGPT?"

mytext = "Okay. GPT, which is an abbreviated from Generative Pretrained Transformer, is a type of language model developed by OpenAI. GPT-3, the latest version of the model, is one of the largest and most powerful language models available today, with billions of parameters. ChatGPT is a variation of the GPT model that is fine-tuned for conversational AI. It's specifically trained to generate human-like responses to natural language inputs. By using a conversational AI model like ChatGPT, you can build chatbots, virtual assistants, and other applications that can understand and respond to human language in a natural way. ChatGPT is based on the transformer architecture, which has proven to be effective for many natural language processing tasks. The model has been trained on a large corpus of text data, allowing it to generate coherent and contextually relevant responses to a wide range of inputs."
print(mytext)
tts(mytext)
# Out:
# Okay. GPT, which is an abbreviated from Generative Pretrained Transformer, is a type of language model developed by OpenAI. GPT-3, the latest version of the model, is one of the largest and most powerful language models available today, with billions of parameters. ChatGPT is a variation of the GPT model that is fine-tuned for conversational AI. It's specifically trained to generate human-like responses to natural language inputs. By using a conversational AI model like ChatGPT, you can build chatbots, virtual assistants, and other applications that can understand and respond to human language in a natural way. ChatGPT is based on the transformer architecture, which has proven to be effective for many natural language processing tasks. The model has been trained on a large corpus of text data, allowing it to generate coherent and contextually relevant responses to a wide range of inputs.
#                 <audio  controls="controls" >
# ...

# %% [markdown]
# DALL-E [link](https://openai.com/dall-e-2/)

# %%
#@markdown Q3: "What is DALL-E and how to pronounce DALL-E?"

mytext = "DALL-E is an artificial intelligence model developed by OpenAI that can generate unique images from textual descriptions. It's based on the transformer architecture, which is commonly used in natural language processing, and has been trained on a large dataset of images and textual descriptions. DALL-E is pronounced as 'dolly'."
print(mytext)
tts(mytext)
# Out:
# DALL-E is an artificial intelligence model developed by OpenAI that can generate unique images from textual descriptions. It's based on the transformer architecture, which is commonly used in natural language processing, and has been trained on a large dataset of images and textual descriptions. DALL-E is pronounced as 'dolly'.
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## C. OpenAI - DALL-E

# %%
#@markdown DALL-E samples (Feb. 13, 2023): 
from IPython.display import Image

img = "5" #@param = [0, 1, 2, 3, 4, 5]

if img == "0":
  txt = "Gogh style painting of a female university student who is excited to learn something new in a classroom"
  url = "https://github.com/MK316/images/raw/main/dalle-sample01.png"
elif img == "1":
  txt = "Guess what description?"
  url = "https://github.com/MK316/images/raw/main/dalle-sample02.png"
elif img == "2":
  txt = "Guess what description?"
  url = "https://github.com/MK316/images/raw/main/dalle-sample03.png"
elif img == "3":
  txt = "Guess what description?"
  url = "https://github.com/MK316/images/raw/main/dalle-sample04.png"
elif img == "4":
  txt = "Guess what description?"
  url = "https://github.com/MK316/images/raw/main/dalle-sample05.png"
elif img == "5":
  txt = "Guess what description?"
  url = "https://github.com/MK316/images/raw/main/dalle-sample06.png"

print("Description: %s"%txt)
print("="*50)
Image(url, width = "1200")
# Out:
# Description: Guess what description?
# ...

# %% [markdown]
# # 🔎 In-class activities - Introduce useful tools to future teachers (group presentation)

# %% [markdown]
# # ⏰ Todo:

# %% [markdown]
# Post one image on Padlet [link](https://padlet.com/miranege/DL2023)

# %% [markdown]
# ---
# # The End
