# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2023/blob/main/Midterm_preview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Midterm test

# %% [markdown]
# [1] Engpro

# %%
#@markdown Install {pyqrcode} and enter link address
# !pip install pyqrcode
# !pip install gtts
import pyqrcode
from pyqrcode import QRCode
from gtts import gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyqrcode in /usr/local/lib/python3.9/dist-packages (1.2.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gtts in /usr/local/lib/python3.9/dist-packages (2.3.1)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.9/dist-packages (from gtts) (2.27.1)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.9/dist-packages (from gtts) (8.1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.27->gtts) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.27->gtts) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.27->gtts) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.27->gtts) (2.0.12)

# %%
#@markdown Define tts(): "sample.mp3"
def tts(txt):
  tts = gTTS(txt, lang='ko')
  tts.save("sample.mp3")
  return Audio("/content/sample.mp3")

# %%
n = "1" #@param = [0,1,2,3]
n = int(n)
paras=["먼저, 전자출결을 시작할게요.",
       "오늘은 시험 문항에 대해 같이 살펴보고, 시험 포맷에 익숙해져 보는 시간을 가지려 합니다. 선생님이 감기로 목소리가 안 좋은 관계로 제가 대신 수업을 보조할게요.",
      "중간고사 시험 유형을 같이 살펴보고, 직접 해 보는 시간을 가지도록 하겠습니다. 질문 있으면 언제든지 질문해 주세요. 같이 검토한 후에는 화면에 바코드를 보여드릴테니 스마트폰으로 찍어서 직접 들어가 보세요.",
      "그럼 목요일에 시간 늦지 않도록 오시고, 핸드폰 충전 확인해서 오세요. "
  ]

mytext = paras[n]
tts(mytext)
Audio("sample.mp3",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown text to say
from IPython.display import Audio
mytext = input("Type text: ")
tts(mytext)
Audio("sample.mp3",autoplay=True)
# Out:
# Type text: 안녕
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# [link](https://docs.google.com/forms/d/11G7RJsB6FUfsPDWz4PKp3I-IwAycysEgNGoqEV7y7-w/edit)

# %%
#@markdown Enter the link, save it as a file, and display
s = "https://forms.gle/6wpdiZuHBMed6MeB7"

# Generate QR code
url = pyqrcode.create(s)

# Create and save the png file naming "myqr.png"
url.svg("myqrcode.svg", scale=10)

from IPython.display import SVG, display
def show_svg(file):
    display(SVG(file))

show_svg("myqrcode.svg")

# %% [markdown]
# #[2] English linguistics

# %% [markdown]
# 0. intro
# 1. Feature questions
# 2. Feature practice
# 3. Feature quiz (group activity)
# 4. Midterm exam types
# 5. Any question?
# 6. Outro

# %%
n = "1" #@param = [0,1,2,3,4, 5, 6]
n = int(n)
paras=["여러분 안녕하세요? 오늘은 김미란 교수님이 감기로 목소리가 안 좋은 관계로 제가 대신 수업을 보조할게요. 먼저, 영어학의이해 시작하기 전에 전자출결을 시작할게요. 두 번 실행할테니 꼭 자동출석하시기 바랍니다.",
       "먼저, 지난 번에 다 풀지 못했던 임용 기출 문제는 이번 중간고사에서 제외할게요. 나중에 기말고사에 포함된다고 알고 계시기 바랍니다. 그러니 꼭 조별로라도 풀어보시기 바랍니다.",
       "두 번째로 할 일은 다수의 소리가 묶였을 때 공통 Feature를 찾는 연습이예요. 이 부분은 제가 코딩을 해 놓았으니 먼저 함께 해 보고, 그룹별로 나와서 조원들이 모두 나와서 같이 풀어보기도 할 거예요. 먼저 데모를 같이 보도록 합시다.",
       "세 번째는 이제 조원이 모두 나와서 한명씩 문제를 풀어볼 거예요. 점수는 조원들 점수를 모두 합하여 계산됩니다."
       "네 번째는 목요일 시험 문항에 대해 같이 살펴보고, 시험 포맷에 익숙해져 보는 시간을 가지려 합니다. 제가 먼저 링크에 가서 같이 풀어보고, 그 다음은 QR 코드를 화면에 보여줄거예요. 그러면 개별적으로 들어가서 잘 작동하는지 확인하는 시간을 드릴 겁니다.",
      "질문 있으면 언제든지 질문해 주세요. ",
      "그럼 목요일에 시간 늦지 않도록 오시고, 핸드폰 및 기기 충전, 인터넷 연결 등을 꼭 확인해서 오세요. "
  ]

mytext = paras[n]
tts(mytext)
Audio("sample.mp3",autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 2. Feature practice & quiz [link](https://github.com/MK316/Spring2023/blob/main/Engling/feature_practice.ipynb)

# %%
#@markdown text to say
from IPython.display import Audio
mytext = input("Type text: ")
tts(mytext)
Audio("sample.mp3",autoplay=True)
# Out:
# Type text: 안녕
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Enter the link, save it as a file, and display
s = "https://forms.gle/R2jKcncMMGGfVbid9"

# Generate QR code
url = pyqrcode.create(s)

# Create and save the png file naming "myqr.png"
url.svg("myqrcode.svg", scale=10)

from IPython.display import SVG, display
def show_svg(file):
    display(SVG(file))

show_svg("myqrcode.svg")
